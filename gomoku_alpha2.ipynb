# %% [markdown]
# <a href="https://colab.research.google.com/github/kutouxiyiji/AlphaZero_Gomoku/blob/master/gomoku_alpha2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
# !git clone https://github.com/kutouxiyiji/AlphaZero_Gomoku.git
# Out:
# Cloning into 'AlphaZero_Gomoku'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 169 (delta 0), reused 0 (delta 0), pack-reused 166
# Receiving objects: 100% (169/169), 6.50 MiB | 30.37 MiB/s, done.
# Resolving deltas: 100% (89/89), done.

# %%
# !ls /content/AlphaZero_Gomoku/*.py
# Out:
# /content/AlphaZero_Gomoku/game.py
# /content/AlphaZero_Gomoku/human_play.py
# /content/AlphaZero_Gomoku/mcts_alphaZero.py
# /content/AlphaZero_Gomoku/mcts_pure.py
# /content/AlphaZero_Gomoku/policy_value_net_keras.py
# /content/AlphaZero_Gomoku/policy_value_net_numpy.py
# /content/AlphaZero_Gomoku/policy_value_net.py
# /content/AlphaZero_Gomoku/policy_value_net_pytorch.py
# /content/AlphaZero_Gomoku/policy_value_net_tensorflow.py
# /content/AlphaZero_Gomoku/train.py

# %%
import sys
sys.path.append('/content/AlphaZero_Gomoku/')

# %%
import game

# %%
from __future__ import print_function
import random
import numpy as np
from collections import defaultdict, deque
from game import Board, Game
from mcts_pure import MCTSPlayer as MCTS_Pure
from mcts_alphaZero import MCTSPlayer
#from policy_value_net import PolicyValueNet  # Theano and Lasagne
from policy_value_net_pytorch import PolicyValueNet  # Pytorch
# from policy_value_net_tensorflow import PolicyValueNet # Tensorflow
# from policy_value_net_keras import PolicyValueNet # Keras

# %%
import human_play

# %%
from __future__ import print_function
import pickle
from game import Board, Game
from mcts_pure import MCTSPlayer as MCTS_Pure
from mcts_alphaZero import MCTSPlayer
from policy_value_net_numpy import PolicyValueNetNumpy
# from policy_value_net import PolicyValueNet  # Theano and Lasagne
from policy_value_net_pytorch import PolicyValueNet  # Pytorch
# from policy_value_net_tensorflow import PolicyValueNet # Tensorflow
# from policy_value_net_keras import PolicyValueNet  # Keras


class Human(object):
    """
    human player
    """

    def __init__(self):
        self.player = None

    def set_player_ind(self, p):
        self.player = p

    def get_action(self, board):
        try:
            location = input("Your move: ")
            if isinstance(location, str):  # for python3
                location = [int(n, 10) for n in location.split(",")]
            move = board.location_to_move(location)
        except Exception as e:
            move = -1
        if move == -1 or move not in board.availables:
            print("invalid move")
            move = self.get_action(board)
        return move

    def __str__(self):
        return "Human {}".format(self.player)


def run():
    n = 5
    width, height = 8, 8
    model_file = '/content/AlphaZero_Gomoku/best_policy_8_8_5.model'
    try:
        board = Board(width=width, height=height, n_in_row=n)
        game = Game(board)

        # ############### human VS AI ###################
        # load the trained policy_value_net in either Theano/Lasagne, PyTorch or TensorFlow

        # best_policy = PolicyValueNet(width, height, model_file = model_file)
        # mcts_player = MCTSPlayer(best_policy.policy_value_fn, c_puct=5, n_playout=400)

        # load the provided model (trained in Theano/Lasagne) into a MCTS player written in pure numpy
        try:
            policy_param = pickle.load(open(model_file, 'rb'))
        except:
            policy_param = pickle.load(open(model_file, 'rb'),
                                       encoding='bytes')  # To support python3
        best_policy = PolicyValueNetNumpy(width, height, policy_param)
        mcts_player = MCTSPlayer(best_policy.policy_value_fn,
                                 c_puct=5,
                                 n_playout=400)  # set larger n_playout for better performance

        # uncomment the following line to play with pure MCTS (it's much weaker even with a larger n_playout)
        # mcts_player = MCTS_Pure(c_puct=5, n_playout=1000)

        # human player, input your move in the format: 2,3
        human = Human()

        # set start_player=0 for human first
        game.start_play(human, mcts_player, start_player=1, is_shown=1)
    except KeyboardInterrupt:
        print('\n\rquit')


if __name__ == '__main__':
    run()

# %%
# -*- coding: utf-8 -*-
"""
An implementation of the training pipeline of AlphaZero for Gomoku

@author: Junxiao Song
"""

from __future__ import print_function
import random
import numpy as np
from collections import defaultdict, deque
from game import Board, Game
from mcts_pure import MCTSPlayer as MCTS_Pure
from mcts_alphaZero import MCTSPlayer
#from policy_value_net import PolicyValueNet  # Theano and Lasagne
from policy_value_net_pytorch import PolicyValueNet  # Pytorch
#from policy_value_net_tensorflow import PolicyValueNet # Tensorflow
# from policy_value_net_keras import PolicyValueNet # Keras


class TrainPipeline():
    def __init__(self, init_model=None):
        # params of the board and the game
        self.board_width = 6
        self.board_height = 6
        self.n_in_row = 4
        self.board = Board(width=self.board_width,
                           height=self.board_height,
                           n_in_row=self.n_in_row)
        self.game = Game(self.board)
        # training params
        self.learn_rate = 2e-3
        self.lr_multiplier = 1.0  # adaptively adjust the learning rate based on KL
        self.temp = 1.0  # the temperature param
        self.n_playout = 400  # num of simulations for each move
        self.c_puct = 5
        self.buffer_size = 10000
        self.batch_size = 512  # mini-batch size for training
        self.data_buffer = deque(maxlen=self.buffer_size)
        self.play_batch_size = 1
        self.epochs = 5  # num of train_steps for each update
        self.kl_targ = 0.02
        self.check_freq = 50
        self.game_batch_num = 1500
        self.best_win_ratio = 0.0
        # num of simulations used for the pure mcts, which is used as
        # the opponent to evaluate the trained policy
        self.pure_mcts_playout_num = 1000
        if init_model:
            # start training from an initial policy-value net
            self.policy_value_net = PolicyValueNet(self.board_width,
                                                   self.board_height,
                                                   model_file=init_model)
        else:
            # start training from a new policy-value net
            self.policy_value_net = PolicyValueNet(self.board_width,
                                                   self.board_height)
        self.mcts_player = MCTSPlayer(self.policy_value_net.policy_value_fn,
                                      c_puct=self.c_puct,
                                      n_playout=self.n_playout,
                                      is_selfplay=1)

    def get_equi_data(self, play_data):
        """augment the data set by rotation and flipping
        play_data: [(state, mcts_prob, winner_z), ..., ...]
        """
        extend_data = []
        for state, mcts_porb, winner in play_data:
            for i in [1, 2, 3, 4]:
                # rotate counterclockwise
                equi_state = np.array([np.rot90(s, i) for s in state])
                equi_mcts_prob = np.rot90(np.flipud(
                    mcts_porb.reshape(self.board_height, self.board_width)), i)
                extend_data.append((equi_state,
                                    np.flipud(equi_mcts_prob).flatten(),
                                    winner))
                # flip horizontally
                equi_state = np.array([np.fliplr(s) for s in equi_state])
                equi_mcts_prob = np.fliplr(equi_mcts_prob)
                extend_data.append((equi_state,
                                    np.flipud(equi_mcts_prob).flatten(),
                                    winner))
        return extend_data

    def collect_selfplay_data(self, n_games=1):
        """collect self-play data for training"""
        for i in range(n_games):
            winner, play_data = self.game.start_self_play(self.mcts_player,
                                                          temp=self.temp)
            play_data = list(play_data)[:]
            self.episode_len = len(play_data)
            # augment the data
            play_data = self.get_equi_data(play_data)
            self.data_buffer.extend(play_data)

    def policy_update(self):
        """update the policy-value net"""
        mini_batch = random.sample(self.data_buffer, self.batch_size)
        state_batch = [data[0] for data in mini_batch]
        mcts_probs_batch = [data[1] for data in mini_batch]
        winner_batch = [data[2] for data in mini_batch]
        old_probs, old_v = self.policy_value_net.policy_value(state_batch)
        for i in range(self.epochs):
            loss, entropy = self.policy_value_net.train_step(
                    state_batch,
                    mcts_probs_batch,
                    winner_batch,
                    self.learn_rate*self.lr_multiplier)
            new_probs, new_v = self.policy_value_net.policy_value(state_batch)
            kl = np.mean(np.sum(old_probs * (
                    np.log(old_probs + 1e-10) - np.log(new_probs + 1e-10)),
                    axis=1)
            )
            if kl > self.kl_targ * 4:  # early stopping if D_KL diverges badly
                break
        # adaptively adjust the learning rate
        if kl > self.kl_targ * 2 and self.lr_multiplier > 0.1:
            self.lr_multiplier /= 1.5
        elif kl < self.kl_targ / 2 and self.lr_multiplier < 10:
            self.lr_multiplier *= 1.5

        explained_var_old = (1 -
                             np.var(np.array(winner_batch) - old_v.flatten()) /
                             np.var(np.array(winner_batch)))
        explained_var_new = (1 -
                             np.var(np.array(winner_batch) - new_v.flatten()) /
                             np.var(np.array(winner_batch)))
        print(("kl:{:.5f},"
               "lr_multiplier:{:.3f},"
               "loss:{},"
               "entropy:{},"
               "explained_var_old:{:.3f},"
               "explained_var_new:{:.3f}"
               ).format(kl,
                        self.lr_multiplier,
                        loss,
                        entropy,
                        explained_var_old,
                        explained_var_new))
        return loss, entropy

    def policy_evaluate(self, n_games=10):
        """
        Evaluate the trained policy by playing against the pure MCTS player
        Note: this is only for monitoring the progress of training
        """
        current_mcts_player = MCTSPlayer(self.policy_value_net.policy_value_fn,
                                         c_puct=self.c_puct,
                                         n_playout=self.n_playout)
        pure_mcts_player = MCTS_Pure(c_puct=5,
                                     n_playout=self.pure_mcts_playout_num)
        win_cnt = defaultdict(int)
        for i in range(n_games):
            winner = self.game.start_play(current_mcts_player,
                                          pure_mcts_player,
                                          start_player=i % 2,
                                          is_shown=0)
            win_cnt[winner] += 1
        win_ratio = 1.0*(win_cnt[1] + 0.5*win_cnt[-1]) / n_games
        print("num_playouts:{}, win: {}, lose: {}, tie:{}".format(
                self.pure_mcts_playout_num,
                win_cnt[1], win_cnt[2], win_cnt[-1]))
        return win_ratio

    def run(self):
        """run the training pipeline"""
        try:
            for i in range(self.game_batch_num):
                self.collect_selfplay_data(self.play_batch_size)
                print("batch i:{}, episode_len:{}".format(
                        i+1, self.episode_len))
                if len(self.data_buffer) > self.batch_size:
                    loss, entropy = self.policy_update()
                # check the performance of the current model,
                # and save the model params
                if (i+1) % self.check_freq == 0:
                    print("current self-play batch: {}".format(i+1))
                    win_ratio = self.policy_evaluate()
                    self.policy_value_net.save_model('./current_policy.model')
                    if win_ratio > self.best_win_ratio:
                        print("New best policy!!!!!!!!")
                        self.best_win_ratio = win_ratio
                        # update the best_policy
                        self.policy_value_net.save_model('./best_policy.model')
                        if (self.best_win_ratio == 1.0 and
                                self.pure_mcts_playout_num < 5000):
                            self.pure_mcts_playout_num += 1000
                            self.best_win_ratio = 0.0
        except KeyboardInterrupt:
            print('\n\rquit')


if __name__ == '__main__':
    training_pipeline = TrainPipeline()
    training_pipeline.run()
# Out:
# /content/AlphaZero_Gomoku/policy_value_net_pytorch.py:51: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   x_act = F.log_softmax(self.act_fc1(x_act))
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:1374: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# batch i:1, episode_len:11
# batch i:2, episode_len:15
# batch i:3, episode_len:9
# batch i:4, episode_len:11
# batch i:5, episode_len:15
# batch i:6, episode_len:15
# kl:0.01258,lr_multiplier:1.000,loss:4.136256217956543,entropy:3.5787582397460938,explained_var_old:0.005,explained_var_new:0.668
# batch i:7, episode_len:19
# kl:0.00569,lr_multiplier:1.500,loss:3.9610424041748047,entropy:3.5761935710906982,explained_var_old:0.668,explained_var_new:0.815
# batch i:8, episode_len:16
# kl:0.00911,lr_multiplier:2.250,loss:4.221441745758057,entropy:3.5719470977783203,explained_var_old:0.406,explained_var_new:0.341
# batch i:9, episode_len:26
# kl:0.00999,lr_multiplier:3.375,loss:4.587114334106445,entropy:3.5293169021606445,explained_var_old:-0.093,explained_var_new:0.127
# batch i:10, episode_len:23
# kl:0.01244,lr_multiplier:3.375,loss:4.481759071350098,entropy:3.5450029373168945,explained_var_old:0.171,explained_var_new:0.182
# batch i:11, episode_len:17
# kl:0.01403,lr_multiplier:3.375,loss:4.339550971984863,entropy:3.5521397590637207,explained_var_old:0.294,explained_var_new:0.289
# batch i:12, episode_len:19
# kl:0.01764,lr_multiplier:3.375,loss:4.275548934936523,entropy:3.5380640029907227,explained_var_old:0.319,explained_var_new:0.286
# batch i:13, episode_len:16
# kl:0.01098,lr_multiplier:3.375,loss:4.4511542320251465,entropy:3.5305376052856445,explained_var_old:0.080,explained_var_new:0.118
# batch i:14, episode_len:15
# kl:0.00826,lr_multiplier:5.062,loss:4.324590682983398,entropy:3.5304512977600098,explained_var_old:0.244,explained_var_new:0.246
# batch i:15, episode_len:10
# kl:0.01380,lr_multiplier:5.062,loss:4.3733415603637695,entropy:3.530407428741455,explained_var_old:0.064,explained_var_new:0.261
# batch i:16, episode_len:17
# kl:0.03151,lr_multiplier:5.062,loss:4.234562873840332,entropy:3.535630226135254,explained_var_old:0.365,explained_var_new:0.378
# batch i:17, episode_len:10
# kl:0.01308,lr_multiplier:5.062,loss:4.317417621612549,entropy:3.5032505989074707,explained_var_old:0.190,explained_var_new:0.271
# batch i:18, episode_len:24
# kl:0.01036,lr_multiplier:5.062,loss:4.345182418823242,entropy:3.5141372680664062,explained_var_old:0.180,explained_var_new:0.276
# batch i:19, episode_len:14
# kl:0.01303,lr_multiplier:5.062,loss:4.277899265289307,entropy:3.5345711708068848,explained_var_old:0.068,explained_var_new:0.292
# batch i:20, episode_len:18
# kl:0.03164,lr_multiplier:5.062,loss:4.14811897277832,entropy:3.4925801753997803,explained_var_old:0.196,explained_var_new:0.371
# batch i:21, episode_len:10
# kl:0.01266,lr_multiplier:5.062,loss:4.124769687652588,entropy:3.476447105407715,explained_var_old:0.223,explained_var_new:0.400
# batch i:22, episode_len:9
# kl:0.01306,lr_multiplier:5.062,loss:4.011547088623047,entropy:3.490326404571533,explained_var_old:0.317,explained_var_new:0.465
# batch i:23, episode_len:13
# kl:0.06395,lr_multiplier:3.375,loss:4.028626918792725,entropy:3.420293092727661,explained_var_old:0.283,explained_var_new:0.437
# batch i:24, episode_len:18
# kl:0.03607,lr_multiplier:3.375,loss:3.9693069458007812,entropy:3.451819896697998,explained_var_old:0.310,explained_var_new:0.426
# batch i:25, episode_len:16
# kl:0.03279,lr_multiplier:3.375,loss:3.906505584716797,entropy:3.3781938552856445,explained_var_old:0.375,explained_var_new:0.495
# batch i:26, episode_len:13
# kl:0.02547,lr_multiplier:3.375,loss:3.95176100730896,entropy:3.4110610485076904,explained_var_old:0.351,explained_var_new:0.453
# batch i:27, episode_len:16
# kl:0.03445,lr_multiplier:3.375,loss:3.903524875640869,entropy:3.3542604446411133,explained_var_old:0.338,explained_var_new:0.471
# batch i:28, episode_len:17
# kl:0.04035,lr_multiplier:2.250,loss:3.8108904361724854,entropy:3.356874465942383,explained_var_old:0.396,explained_var_new:0.538
# batch i:29, episode_len:11
# kl:0.01408,lr_multiplier:2.250,loss:3.8295867443084717,entropy:3.341716766357422,explained_var_old:0.405,explained_var_new:0.536
# batch i:30, episode_len:12
# kl:0.01299,lr_multiplier:2.250,loss:3.8512492179870605,entropy:3.343513250350952,explained_var_old:0.367,explained_var_new:0.505
# batch i:31, episode_len:16
# kl:0.02048,lr_multiplier:2.250,loss:3.8010787963867188,entropy:3.329871416091919,explained_var_old:0.397,explained_var_new:0.520
# batch i:32, episode_len:16
# kl:0.01835,lr_multiplier:2.250,loss:3.770064115524292,entropy:3.332181692123413,explained_var_old:0.391,explained_var_new:0.572
# batch i:33, episode_len:11
# kl:0.02244,lr_multiplier:2.250,loss:3.7801737785339355,entropy:3.306734561920166,explained_var_old:0.409,explained_var_new:0.548
# batch i:34, episode_len:12
# kl:0.02849,lr_multiplier:2.250,loss:3.7541143894195557,entropy:3.2919793128967285,explained_var_old:0.418,explained_var_new:0.553
# batch i:35, episode_len:14
# kl:0.03010,lr_multiplier:2.250,loss:3.7121899127960205,entropy:3.2895898818969727,explained_var_old:0.456,explained_var_new:0.571
# batch i:36, episode_len:12
# kl:0.04272,lr_multiplier:1.500,loss:3.6879236698150635,entropy:3.2742419242858887,explained_var_old:0.448,explained_var_new:0.581
# batch i:37, episode_len:9
# kl:0.01719,lr_multiplier:1.500,loss:3.66456937789917,entropy:3.24326491355896,explained_var_old:0.492,explained_var_new:0.592
# batch i:38, episode_len:18
# kl:0.03748,lr_multiplier:1.500,loss:3.7318623065948486,entropy:3.2983319759368896,explained_var_old:0.469,explained_var_new:0.563
# batch i:39, episode_len:20
# kl:0.03499,lr_multiplier:1.500,loss:3.679111957550049,entropy:3.2387332916259766,explained_var_old:0.467,explained_var_new:0.590
# batch i:40, episode_len:15
# kl:0.02216,lr_multiplier:1.500,loss:3.686222791671753,entropy:3.251589775085449,explained_var_old:0.464,explained_var_new:0.589
# batch i:41, episode_len:15
# kl:0.01999,lr_multiplier:1.500,loss:3.657816171646118,entropy:3.20625901222229,explained_var_old:0.445,explained_var_new:0.579
# batch i:42, episode_len:9
# kl:0.03086,lr_multiplier:1.500,loss:3.698988676071167,entropy:3.209023952484131,explained_var_old:0.402,explained_var_new:0.534
# batch i:43, episode_len:14
# kl:0.02886,lr_multiplier:1.500,loss:3.6811723709106445,entropy:3.2354795932769775,explained_var_old:0.392,explained_var_new:0.531
# batch i:44, episode_len:16
# kl:0.02435,lr_multiplier:1.500,loss:3.598524808883667,entropy:3.177095890045166,explained_var_old:0.457,explained_var_new:0.592
# batch i:45, episode_len:9
# kl:0.04195,lr_multiplier:1.000,loss:3.6292905807495117,entropy:3.1866226196289062,explained_var_old:0.422,explained_var_new:0.563
# batch i:46, episode_len:12
# kl:0.01004,lr_multiplier:1.000,loss:3.679490089416504,entropy:3.21235990524292,explained_var_old:0.452,explained_var_new:0.539
# batch i:47, episode_len:9
# kl:0.01521,lr_multiplier:1.000,loss:3.6741654872894287,entropy:3.1982929706573486,explained_var_old:0.441,explained_var_new:0.551
# batch i:48, episode_len:13
# kl:0.01273,lr_multiplier:1.000,loss:3.6561522483825684,entropy:3.2057461738586426,explained_var_old:0.437,explained_var_new:0.555
# batch i:49, episode_len:13
# kl:0.01380,lr_multiplier:1.000,loss:3.6868209838867188,entropy:3.222184419631958,explained_var_old:0.384,explained_var_new:0.534
# batch i:50, episode_len:16
# kl:0.01363,lr_multiplier:1.000,loss:3.6436822414398193,entropy:3.2111380100250244,explained_var_old:0.482,explained_var_new:0.574
# current self-play batch: 50
# num_playouts:1000, win: 4, lose: 6, tie:0
# New best policy!!!!!!!!
# batch i:51, episode_len:10
# kl:0.02402,lr_multiplier:1.000,loss:3.668895959854126,entropy:3.181164026260376,explained_var_old:0.405,explained_var_new:0.526
# batch i:52, episode_len:15
# kl:0.01393,lr_multiplier:1.000,loss:3.5844972133636475,entropy:3.1501808166503906,explained_var_old:0.450,explained_var_new:0.571
# batch i:53, episode_len:18
# kl:0.01495,lr_multiplier:1.000,loss:3.600811719894409,entropy:3.1535825729370117,explained_var_old:0.450,explained_var_new:0.559
# batch i:54, episode_len:7
# kl:0.01179,lr_multiplier:1.000,loss:3.651421546936035,entropy:3.1597208976745605,explained_var_old:0.423,explained_var_new:0.525
# batch i:55, episode_len:12
# kl:0.01805,lr_multiplier:1.000,loss:3.5727548599243164,entropy:3.1407036781311035,explained_var_old:0.453,explained_var_new:0.544
# batch i:56, episode_len:13
# kl:0.01585,lr_multiplier:1.000,loss:3.5928170680999756,entropy:3.1257715225219727,explained_var_old:0.477,explained_var_new:0.569
# batch i:57, episode_len:14
# kl:0.01317,lr_multiplier:1.000,loss:3.637566566467285,entropy:3.160581111907959,explained_var_old:0.386,explained_var_new:0.505
# batch i:58, episode_len:11
# kl:0.02442,lr_multiplier:1.000,loss:3.5281128883361816,entropy:3.064756155014038,explained_var_old:0.477,explained_var_new:0.572
# batch i:59, episode_len:14
# kl:0.03264,lr_multiplier:1.000,loss:3.5017213821411133,entropy:3.077935218811035,explained_var_old:0.501,explained_var_new:0.615
# batch i:60, episode_len:17
# kl:0.01407,lr_multiplier:1.000,loss:3.4874398708343506,entropy:3.090160369873047,explained_var_old:0.499,explained_var_new:0.603
# batch i:61, episode_len:10
# kl:0.02578,lr_multiplier:1.000,loss:3.5797386169433594,entropy:3.1398115158081055,explained_var_old:0.431,explained_var_new:0.550
# batch i:62, episode_len:16
# kl:0.02467,lr_multiplier:1.000,loss:3.5899200439453125,entropy:3.108419179916382,explained_var_old:0.412,explained_var_new:0.522
# batch i:63, episode_len:12
# kl:0.02315,lr_multiplier:1.000,loss:3.546445846557617,entropy:3.084378242492676,explained_var_old:0.444,explained_var_new:0.568
# batch i:64, episode_len:14
# kl:0.02247,lr_multiplier:1.000,loss:3.5941433906555176,entropy:3.133479595184326,explained_var_old:0.435,explained_var_new:0.521
# batch i:65, episode_len:18
# kl:0.02461,lr_multiplier:1.000,loss:3.5707554817199707,entropy:3.0996925830841064,explained_var_old:0.425,explained_var_new:0.524
# batch i:66, episode_len:14
# kl:0.02880,lr_multiplier:1.000,loss:3.4647433757781982,entropy:3.0637292861938477,explained_var_old:0.477,explained_var_new:0.617
# batch i:67, episode_len:15
# kl:0.01753,lr_multiplier:1.000,loss:3.5878477096557617,entropy:3.0676662921905518,explained_var_old:0.361,explained_var_new:0.484
# batch i:68, episode_len:15
# kl:0.01606,lr_multiplier:1.000,loss:3.651643753051758,entropy:3.108715534210205,explained_var_old:0.338,explained_var_new:0.459
# batch i:69, episode_len:8
# kl:0.01796,lr_multiplier:1.000,loss:3.5706021785736084,entropy:3.049628734588623,explained_var_old:0.353,explained_var_new:0.464
# batch i:70, episode_len:13
# kl:0.01528,lr_multiplier:1.000,loss:3.6456637382507324,entropy:3.0332651138305664,explained_var_old:0.354,explained_var_new:0.437
# batch i:71, episode_len:14
# kl:0.01798,lr_multiplier:1.000,loss:3.4337337017059326,entropy:3.0075552463531494,explained_var_old:0.452,explained_var_new:0.556
# batch i:72, episode_len:8
# kl:0.01544,lr_multiplier:1.000,loss:3.559933662414551,entropy:3.0521106719970703,explained_var_old:0.397,explained_var_new:0.503
# batch i:73, episode_len:21
# kl:0.02313,lr_multiplier:1.000,loss:3.507456064224243,entropy:3.057368516921997,explained_var_old:0.431,explained_var_new:0.537
# batch i:74, episode_len:20
# kl:0.01630,lr_multiplier:1.000,loss:3.513575792312622,entropy:3.0344595909118652,explained_var_old:0.360,explained_var_new:0.502
# batch i:75, episode_len:12
# kl:0.01853,lr_multiplier:1.000,loss:3.5067434310913086,entropy:3.0070629119873047,explained_var_old:0.463,explained_var_new:0.555
# batch i:76, episode_len:15
# kl:0.02307,lr_multiplier:1.000,loss:3.569110155105591,entropy:3.0296852588653564,explained_var_old:0.328,explained_var_new:0.465
# batch i:77, episode_len:20
# kl:0.01639,lr_multiplier:1.000,loss:3.622636556625366,entropy:3.07078218460083,explained_var_old:0.345,explained_var_new:0.435
# batch i:78, episode_len:17
# kl:0.01787,lr_multiplier:1.000,loss:3.481912612915039,entropy:3.036137580871582,explained_var_old:0.432,explained_var_new:0.524
# batch i:79, episode_len:13
# kl:0.02455,lr_multiplier:1.000,loss:3.5533204078674316,entropy:2.9970595836639404,explained_var_old:0.382,explained_var_new:0.486
# batch i:80, episode_len:18
# kl:0.02761,lr_multiplier:1.000,loss:3.564237594604492,entropy:3.0245208740234375,explained_var_old:0.387,explained_var_new:0.484
# batch i:81, episode_len:15
# kl:0.01553,lr_multiplier:1.000,loss:3.6086668968200684,entropy:3.0739285945892334,explained_var_old:0.316,explained_var_new:0.447
# batch i:82, episode_len:18
# kl:0.01596,lr_multiplier:1.000,loss:3.5868585109710693,entropy:3.055281162261963,explained_var_old:0.361,explained_var_new:0.483
# batch i:83, episode_len:9
# kl:0.01530,lr_multiplier:1.000,loss:3.629582643508911,entropy:3.063400983810425,explained_var_old:0.356,explained_var_new:0.430
# batch i:84, episode_len:12
# kl:0.01539,lr_multiplier:1.000,loss:3.563403844833374,entropy:3.0303995609283447,explained_var_old:0.384,explained_var_new:0.473
# batch i:85, episode_len:16
# kl:0.01953,lr_multiplier:1.000,loss:3.543532609939575,entropy:2.971330165863037,explained_var_old:0.306,explained_var_new:0.439
# batch i:86, episode_len:13
# kl:0.03004,lr_multiplier:1.000,loss:3.6225507259368896,entropy:3.008302927017212,explained_var_old:0.257,explained_var_new:0.395
# batch i:87, episode_len:9
# kl:0.01611,lr_multiplier:1.000,loss:3.5988731384277344,entropy:3.026481866836548,explained_var_old:0.301,explained_var_new:0.428
# batch i:88, episode_len:22
# kl:0.02604,lr_multiplier:1.000,loss:3.589012384414673,entropy:3.016793966293335,explained_var_old:0.336,explained_var_new:0.447
# batch i:89, episode_len:10
# kl:0.03007,lr_multiplier:1.000,loss:3.5383615493774414,entropy:2.9337408542633057,explained_var_old:0.311,explained_var_new:0.411
# batch i:90, episode_len:7
# kl:0.01543,lr_multiplier:1.000,loss:3.6100871562957764,entropy:3.007225275039673,explained_var_old:0.313,explained_var_new:0.410
# batch i:91, episode_len:11
# kl:0.02408,lr_multiplier:1.000,loss:3.5022220611572266,entropy:3.0026187896728516,explained_var_old:0.396,explained_var_new:0.476
# batch i:92, episode_len:13
# kl:0.02629,lr_multiplier:1.000,loss:3.512744188308716,entropy:2.955923080444336,explained_var_old:0.335,explained_var_new:0.442
# batch i:93, episode_len:17
# kl:0.01546,lr_multiplier:1.000,loss:3.54030179977417,entropy:2.970496892929077,explained_var_old:0.348,explained_var_new:0.440
# batch i:94, episode_len:11
# kl:0.03007,lr_multiplier:1.000,loss:3.408925771713257,entropy:2.9142861366271973,explained_var_old:0.350,explained_var_new:0.487
# batch i:95, episode_len:12
# kl:0.02262,lr_multiplier:1.000,loss:3.5378077030181885,entropy:2.903446674346924,explained_var_old:0.289,explained_var_new:0.395
# batch i:96, episode_len:14
# kl:0.03372,lr_multiplier:1.000,loss:3.485607862472534,entropy:2.9487533569335938,explained_var_old:0.342,explained_var_new:0.437
# batch i:97, episode_len:11
# kl:0.02438,lr_multiplier:1.000,loss:3.574007749557495,entropy:2.9588048458099365,explained_var_old:0.264,explained_var_new:0.395
# batch i:98, episode_len:9
# kl:0.02227,lr_multiplier:1.000,loss:3.5682761669158936,entropy:2.9760212898254395,explained_var_old:0.289,explained_var_new:0.379
# batch i:99, episode_len:9
# kl:0.02779,lr_multiplier:1.000,loss:3.529600143432617,entropy:2.930213451385498,explained_var_old:0.326,explained_var_new:0.411
# batch i:100, episode_len:10
# kl:0.02422,lr_multiplier:1.000,loss:3.524704933166504,entropy:2.9086971282958984,explained_var_old:0.311,explained_var_new:0.427
# current self-play batch: 100
# num_playouts:1000, win: 2, lose: 8, tie:0
# batch i:101, episode_len:9
# kl:0.02507,lr_multiplier:1.000,loss:3.433389663696289,entropy:2.885849952697754,explained_var_old:0.384,explained_var_new:0.450
# batch i:102, episode_len:17
# kl:0.02930,lr_multiplier:1.000,loss:3.43113374710083,entropy:2.8726911544799805,explained_var_old:0.337,explained_var_new:0.452
# batch i:103, episode_len:19
# kl:0.01716,lr_multiplier:1.000,loss:3.5285449028015137,entropy:2.9249794483184814,explained_var_old:0.304,explained_var_new:0.404
# batch i:104, episode_len:9
# kl:0.01845,lr_multiplier:1.000,loss:3.4207510948181152,entropy:2.915836811065674,explained_var_old:0.317,explained_var_new:0.454
# batch i:105, episode_len:13
# kl:0.03378,lr_multiplier:1.000,loss:3.4028947353363037,entropy:2.814176559448242,explained_var_old:0.293,explained_var_new:0.424
# batch i:106, episode_len:10
# kl:0.03101,lr_multiplier:1.000,loss:3.4310312271118164,entropy:2.8222546577453613,explained_var_old:0.306,explained_var_new:0.427
# batch i:107, episode_len:14
# kl:0.02975,lr_multiplier:1.000,loss:3.517686367034912,entropy:2.904085636138916,explained_var_old:0.247,explained_var_new:0.387
# batch i:108, episode_len:11
# kl:0.03080,lr_multiplier:1.000,loss:3.4615230560302734,entropy:2.8366427421569824,explained_var_old:0.271,explained_var_new:0.380
# batch i:109, episode_len:23
# kl:0.03705,lr_multiplier:1.000,loss:3.4529731273651123,entropy:2.821847677230835,explained_var_old:0.259,explained_var_new:0.391
# batch i:110, episode_len:13
# kl:0.02622,lr_multiplier:1.000,loss:3.4056289196014404,entropy:2.8097662925720215,explained_var_old:0.234,explained_var_new:0.386
# batch i:111, episode_len:10
# kl:0.02145,lr_multiplier:1.000,loss:3.423940896987915,entropy:2.7866053581237793,explained_var_old:0.349,explained_var_new:0.432
# batch i:112, episode_len:10
# kl:0.03690,lr_multiplier:1.000,loss:3.413609027862549,entropy:2.862104654312134,explained_var_old:0.288,explained_var_new:0.427
# batch i:113, episode_len:14
# kl:0.03561,lr_multiplier:1.000,loss:3.4108433723449707,entropy:2.8107197284698486,explained_var_old:0.338,explained_var_new:0.442
# batch i:114, episode_len:12
# kl:0.02093,lr_multiplier:1.000,loss:3.3667638301849365,entropy:2.8076462745666504,explained_var_old:0.289,explained_var_new:0.425
# batch i:115, episode_len:11
# kl:0.02833,lr_multiplier:1.000,loss:3.308570146560669,entropy:2.7668488025665283,explained_var_old:0.349,explained_var_new:0.473
# batch i:116, episode_len:9
# kl:0.02687,lr_multiplier:1.000,loss:3.4069223403930664,entropy:2.836484670639038,explained_var_old:0.240,explained_var_new:0.437
# batch i:117, episode_len:9
# kl:0.02027,lr_multiplier:1.000,loss:3.4117655754089355,entropy:2.8329453468322754,explained_var_old:0.302,explained_var_new:0.427
# batch i:118, episode_len:16
# kl:0.03720,lr_multiplier:1.000,loss:3.3185133934020996,entropy:2.727585792541504,explained_var_old:0.313,explained_var_new:0.443
# batch i:119, episode_len:13
# kl:0.01871,lr_multiplier:1.000,loss:3.2610645294189453,entropy:2.7781357765197754,explained_var_old:0.383,explained_var_new:0.511
# batch i:120, episode_len:10
# kl:0.03065,lr_multiplier:1.000,loss:3.314836025238037,entropy:2.796924114227295,explained_var_old:0.381,explained_var_new:0.509
# batch i:121, episode_len:11
# kl:0.03838,lr_multiplier:1.000,loss:3.327580451965332,entropy:2.7574949264526367,explained_var_old:0.285,explained_var_new:0.434
# batch i:122, episode_len:10
# kl:0.03147,lr_multiplier:1.000,loss:3.371654987335205,entropy:2.825761318206787,explained_var_old:0.293,explained_var_new:0.431
# batch i:123, episode_len:11
# kl:0.02747,lr_multiplier:1.000,loss:3.3636698722839355,entropy:2.7968525886535645,explained_var_old:0.312,explained_var_new:0.435
# batch i:124, episode_len:10
# kl:0.02711,lr_multiplier:1.000,loss:3.3368101119995117,entropy:2.7209439277648926,explained_var_old:0.264,explained_var_new:0.409
# batch i:125, episode_len:7
# kl:0.03186,lr_multiplier:1.000,loss:3.4000823497772217,entropy:2.8109066486358643,explained_var_old:0.235,explained_var_new:0.385
# batch i:126, episode_len:8
# kl:0.03118,lr_multiplier:1.000,loss:3.3692030906677246,entropy:2.744596481323242,explained_var_old:0.264,explained_var_new:0.388
# batch i:127, episode_len:14
# kl:0.03001,lr_multiplier:1.000,loss:3.332536220550537,entropy:2.7121224403381348,explained_var_old:0.235,explained_var_new:0.392
# batch i:128, episode_len:7
# kl:0.04238,lr_multiplier:0.667,loss:3.356593132019043,entropy:2.7515792846679688,explained_var_old:0.269,explained_var_new:0.422
# batch i:129, episode_len:18
# kl:0.01199,lr_multiplier:0.667,loss:3.3728878498077393,entropy:2.7665064334869385,explained_var_old:0.314,explained_var_new:0.402
# batch i:130, episode_len:15
# kl:0.01989,lr_multiplier:0.667,loss:3.3020811080932617,entropy:2.705991268157959,explained_var_old:0.337,explained_var_new:0.428
# batch i:131, episode_len:14
# kl:0.01415,lr_multiplier:0.667,loss:3.2909598350524902,entropy:2.7173728942871094,explained_var_old:0.315,explained_var_new:0.406
# batch i:132, episode_len:11
# kl:0.01597,lr_multiplier:0.667,loss:3.3384203910827637,entropy:2.758667230606079,explained_var_old:0.279,explained_var_new:0.393
# batch i:133, episode_len:8
# kl:0.01960,lr_multiplier:0.667,loss:3.2499351501464844,entropy:2.6427841186523438,explained_var_old:0.338,explained_var_new:0.428
# batch i:134, episode_len:10
# kl:0.01656,lr_multiplier:0.667,loss:3.2649412155151367,entropy:2.684260129928589,explained_var_old:0.366,explained_var_new:0.465
# batch i:135, episode_len:10
# kl:0.01229,lr_multiplier:0.667,loss:3.2460336685180664,entropy:2.709652900695801,explained_var_old:0.301,explained_var_new:0.436
# batch i:136, episode_len:9
# kl:0.01623,lr_multiplier:0.667,loss:3.314570903778076,entropy:2.7361645698547363,explained_var_old:0.309,explained_var_new:0.412
# batch i:137, episode_len:7
# kl:0.01590,lr_multiplier:0.667,loss:3.321678400039673,entropy:2.7017877101898193,explained_var_old:0.314,explained_var_new:0.405
# batch i:138, episode_len:8
# kl:0.01793,lr_multiplier:0.667,loss:3.271817207336426,entropy:2.6869616508483887,explained_var_old:0.298,explained_var_new:0.423
# batch i:139, episode_len:12
# kl:0.02112,lr_multiplier:0.667,loss:3.1672418117523193,entropy:2.6384575366973877,explained_var_old:0.387,explained_var_new:0.482
# batch i:140, episode_len:11
# kl:0.01831,lr_multiplier:0.667,loss:3.2633728981018066,entropy:2.706045627593994,explained_var_old:0.357,explained_var_new:0.459
# batch i:141, episode_len:10
# kl:0.01653,lr_multiplier:0.667,loss:3.2601428031921387,entropy:2.64035701751709,explained_var_old:0.246,explained_var_new:0.405
# batch i:142, episode_len:15
# kl:0.01844,lr_multiplier:0.667,loss:3.2043869495391846,entropy:2.6160576343536377,explained_var_old:0.324,explained_var_new:0.435
# batch i:143, episode_len:8
# kl:0.01764,lr_multiplier:0.667,loss:3.2022640705108643,entropy:2.6688122749328613,explained_var_old:0.373,explained_var_new:0.471
# batch i:144, episode_len:13
# kl:0.01997,lr_multiplier:0.667,loss:3.1803605556488037,entropy:2.681713342666626,explained_var_old:0.378,explained_var_new:0.495
# batch i:145, episode_len:9
# kl:0.02150,lr_multiplier:0.667,loss:3.2282419204711914,entropy:2.6757972240448,explained_var_old:0.315,explained_var_new:0.438
# batch i:146, episode_len:11
# kl:0.01501,lr_multiplier:0.667,loss:3.1995129585266113,entropy:2.6208763122558594,explained_var_old:0.331,explained_var_new:0.432
# batch i:147, episode_len:11
# kl:0.01572,lr_multiplier:0.667,loss:3.237110137939453,entropy:2.6609017848968506,explained_var_old:0.300,explained_var_new:0.426
# batch i:148, episode_len:14
# kl:0.01984,lr_multiplier:0.667,loss:3.1640095710754395,entropy:2.6586992740631104,explained_var_old:0.374,explained_var_new:0.493
# batch i:149, episode_len:11
# kl:0.01296,lr_multiplier:0.667,loss:3.2047066688537598,entropy:2.609283447265625,explained_var_old:0.309,explained_var_new:0.445
# batch i:150, episode_len:16
# kl:0.02083,lr_multiplier:0.667,loss:3.284865140914917,entropy:2.695178270339966,explained_var_old:0.317,explained_var_new:0.423
# current self-play batch: 150
# num_playouts:1000, win: 3, lose: 7, tie:0
# batch i:151, episode_len:16
# kl:0.01291,lr_multiplier:0.667,loss:3.3001370429992676,entropy:2.7024970054626465,explained_var_old:0.262,explained_var_new:0.375
# batch i:152, episode_len:16
# kl:0.02460,lr_multiplier:0.667,loss:3.2240052223205566,entropy:2.649052619934082,explained_var_old:0.316,explained_var_new:0.436
# batch i:153, episode_len:7
# kl:0.01857,lr_multiplier:0.667,loss:3.165524482727051,entropy:2.648271322250366,explained_var_old:0.347,explained_var_new:0.463
# batch i:154, episode_len:9
# kl:0.02053,lr_multiplier:0.667,loss:3.220278024673462,entropy:2.578766345977783,explained_var_old:0.257,explained_var_new:0.401
# batch i:155, episode_len:8
# kl:0.02447,lr_multiplier:0.667,loss:3.2443044185638428,entropy:2.6217782497406006,explained_var_old:0.294,explained_var_new:0.429
# batch i:156, episode_len:13
# kl:0.01503,lr_multiplier:0.667,loss:3.234846830368042,entropy:2.705869674682617,explained_var_old:0.326,explained_var_new:0.430
# batch i:157, episode_len:7
# kl:0.01524,lr_multiplier:0.667,loss:3.3217973709106445,entropy:2.6816415786743164,explained_var_old:0.240,explained_var_new:0.364
# batch i:158, episode_len:14
# kl:0.01719,lr_multiplier:0.667,loss:3.1821305751800537,entropy:2.6062633991241455,explained_var_old:0.315,explained_var_new:0.439
# batch i:159, episode_len:14
# kl:0.01642,lr_multiplier:0.667,loss:3.133061408996582,entropy:2.5777900218963623,explained_var_old:0.397,explained_var_new:0.483
# batch i:160, episode_len:15
# kl:0.01756,lr_multiplier:0.667,loss:3.1645278930664062,entropy:2.6012392044067383,explained_var_old:0.324,explained_var_new:0.439
# batch i:161, episode_len:8
# kl:0.02330,lr_multiplier:0.667,loss:3.1672511100769043,entropy:2.6454739570617676,explained_var_old:0.323,explained_var_new:0.450
# batch i:162, episode_len:10
# kl:0.02495,lr_multiplier:0.667,loss:3.1738202571868896,entropy:2.6274988651275635,explained_var_old:0.318,explained_var_new:0.450
# batch i:163, episode_len:10
# kl:0.02904,lr_multiplier:0.667,loss:3.0957207679748535,entropy:2.5573196411132812,explained_var_old:0.385,explained_var_new:0.474
# batch i:164, episode_len:8
# kl:0.03007,lr_multiplier:0.667,loss:3.1786909103393555,entropy:2.565760850906372,explained_var_old:0.313,explained_var_new:0.446
# batch i:165, episode_len:16
# kl:0.01781,lr_multiplier:0.667,loss:3.1045703887939453,entropy:2.588029384613037,explained_var_old:0.375,explained_var_new:0.481
# batch i:166, episode_len:13
# kl:0.03047,lr_multiplier:0.667,loss:3.0798983573913574,entropy:2.5881450176239014,explained_var_old:0.364,explained_var_new:0.489
# batch i:167, episode_len:9
# kl:0.01341,lr_multiplier:0.667,loss:3.1809239387512207,entropy:2.594625473022461,explained_var_old:0.270,explained_var_new:0.415
# batch i:168, episode_len:13
# kl:0.01922,lr_multiplier:0.667,loss:3.1177072525024414,entropy:2.6156232357025146,explained_var_old:0.385,explained_var_new:0.512
# batch i:169, episode_len:7
# kl:0.01579,lr_multiplier:0.667,loss:3.1296603679656982,entropy:2.5615124702453613,explained_var_old:0.330,explained_var_new:0.456
# batch i:170, episode_len:8
# kl:0.02270,lr_multiplier:0.667,loss:3.1730875968933105,entropy:2.6019465923309326,explained_var_old:0.327,explained_var_new:0.452
# batch i:171, episode_len:15
# kl:0.02432,lr_multiplier:0.667,loss:3.129223585128784,entropy:2.6346447467803955,explained_var_old:0.378,explained_var_new:0.494
# batch i:172, episode_len:13
# kl:0.02246,lr_multiplier:0.667,loss:3.0829498767852783,entropy:2.587705373764038,explained_var_old:0.361,explained_var_new:0.482
# batch i:173, episode_len:9
# kl:0.02381,lr_multiplier:0.667,loss:3.1562538146972656,entropy:2.5591254234313965,explained_var_old:0.300,explained_var_new:0.454
# batch i:174, episode_len:14
# kl:0.02398,lr_multiplier:0.667,loss:3.082014560699463,entropy:2.537456512451172,explained_var_old:0.340,explained_var_new:0.475
# batch i:175, episode_len:9
# kl:0.01789,lr_multiplier:0.667,loss:3.2109832763671875,entropy:2.601715087890625,explained_var_old:0.266,explained_var_new:0.377
# batch i:176, episode_len:9
# kl:0.02663,lr_multiplier:0.667,loss:3.035902500152588,entropy:2.553114175796509,explained_var_old:0.377,explained_var_new:0.509
# batch i:177, episode_len:11
# kl:0.02743,lr_multiplier:0.667,loss:3.0878148078918457,entropy:2.4893922805786133,explained_var_old:0.317,explained_var_new:0.423
# batch i:178, episode_len:8
# kl:0.02409,lr_multiplier:0.667,loss:3.0565710067749023,entropy:2.4912569522857666,explained_var_old:0.339,explained_var_new:0.457
# batch i:179, episode_len:13
# kl:0.02144,lr_multiplier:0.667,loss:3.0887272357940674,entropy:2.5589706897735596,explained_var_old:0.388,explained_var_new:0.522
# batch i:180, episode_len:16
# kl:0.02354,lr_multiplier:0.667,loss:2.964916467666626,entropy:2.5321714878082275,explained_var_old:0.404,explained_var_new:0.513
# batch i:181, episode_len:7
# kl:0.01880,lr_multiplier:0.667,loss:2.9985058307647705,entropy:2.540872097015381,explained_var_old:0.423,explained_var_new:0.531
# batch i:182, episode_len:11
# kl:0.03004,lr_multiplier:0.667,loss:3.0422511100769043,entropy:2.543376922607422,explained_var_old:0.380,explained_var_new:0.530
# batch i:183, episode_len:9
# kl:0.01873,lr_multiplier:0.667,loss:3.104736804962158,entropy:2.510918378829956,explained_var_old:0.345,explained_var_new:0.489
# batch i:184, episode_len:7
# kl:0.02160,lr_multiplier:0.667,loss:3.072740077972412,entropy:2.5542032718658447,explained_var_old:0.306,explained_var_new:0.474
# batch i:185, episode_len:12
# kl:0.01990,lr_multiplier:0.667,loss:3.104525327682495,entropy:2.5627400875091553,explained_var_old:0.302,explained_var_new:0.435
# batch i:186, episode_len:11
# kl:0.03498,lr_multiplier:0.667,loss:2.983530044555664,entropy:2.5264248847961426,explained_var_old:0.402,explained_var_new:0.515
# batch i:187, episode_len:11
# kl:0.01666,lr_multiplier:0.667,loss:3.0435662269592285,entropy:2.4852066040039062,explained_var_old:0.387,explained_var_new:0.487
# batch i:188, episode_len:7
# kl:0.02643,lr_multiplier:0.667,loss:3.0831477642059326,entropy:2.574558973312378,explained_var_old:0.332,explained_var_new:0.475
# batch i:189, episode_len:12
# kl:0.02507,lr_multiplier:0.667,loss:2.9615249633789062,entropy:2.511427164077759,explained_var_old:0.423,explained_var_new:0.551
# batch i:190, episode_len:9
# kl:0.02930,lr_multiplier:0.667,loss:2.9009366035461426,entropy:2.4035422801971436,explained_var_old:0.413,explained_var_new:0.549
# batch i:191, episode_len:11
# kl:0.01817,lr_multiplier:0.667,loss:2.968048572540283,entropy:2.430327892303467,explained_var_old:0.377,explained_var_new:0.493
# batch i:192, episode_len:12
# kl:0.03714,lr_multiplier:0.667,loss:2.9652724266052246,entropy:2.501193046569824,explained_var_old:0.389,explained_var_new:0.515
# batch i:193, episode_len:15
# kl:0.03644,lr_multiplier:0.667,loss:3.0173187255859375,entropy:2.503166437149048,explained_var_old:0.373,explained_var_new:0.518
# batch i:194, episode_len:14
# kl:0.02011,lr_multiplier:0.667,loss:3.085573673248291,entropy:2.53800630569458,explained_var_old:0.360,explained_var_new:0.466
# batch i:195, episode_len:7
# kl:0.03071,lr_multiplier:0.667,loss:3.037796974182129,entropy:2.559561014175415,explained_var_old:0.388,explained_var_new:0.500
# batch i:196, episode_len:15
# kl:0.02025,lr_multiplier:0.667,loss:2.943275213241577,entropy:2.479321002960205,explained_var_old:0.430,explained_var_new:0.536
# batch i:197, episode_len:16
# kl:0.02517,lr_multiplier:0.667,loss:2.970796585083008,entropy:2.4218151569366455,explained_var_old:0.408,explained_var_new:0.526
# batch i:198, episode_len:8
# kl:0.02075,lr_multiplier:0.667,loss:2.991966724395752,entropy:2.533921241760254,explained_var_old:0.368,explained_var_new:0.484
# batch i:199, episode_len:10
# kl:0.01874,lr_multiplier:0.667,loss:2.963090181350708,entropy:2.5015292167663574,explained_var_old:0.379,explained_var_new:0.501
# batch i:200, episode_len:9
# kl:0.02538,lr_multiplier:0.667,loss:2.91005277633667,entropy:2.3445303440093994,explained_var_old:0.397,explained_var_new:0.518
# current self-play batch: 200
# num_playouts:1000, win: 6, lose: 4, tie:0
# New best policy!!!!!!!!
# batch i:201, episode_len:11
# kl:0.01892,lr_multiplier:0.667,loss:2.891679048538208,entropy:2.356783390045166,explained_var_old:0.408,explained_var_new:0.525
# batch i:202, episode_len:11
# kl:0.02188,lr_multiplier:0.667,loss:2.8856992721557617,entropy:2.43509840965271,explained_var_old:0.409,explained_var_new:0.557
# batch i:203, episode_len:12
# kl:0.01686,lr_multiplier:0.667,loss:2.894784688949585,entropy:2.391972541809082,explained_var_old:0.418,explained_var_new:0.540
# batch i:204, episode_len:25
# kl:0.02853,lr_multiplier:0.667,loss:2.9354379177093506,entropy:2.436554431915283,explained_var_old:0.332,explained_var_new:0.474
# batch i:205, episode_len:11
# kl:0.02471,lr_multiplier:0.667,loss:2.8105411529541016,entropy:2.411344528198242,explained_var_old:0.459,explained_var_new:0.581
# batch i:206, episode_len:9
# kl:0.02998,lr_multiplier:0.667,loss:2.8474175930023193,entropy:2.3976376056671143,explained_var_old:0.400,explained_var_new:0.550
# batch i:207, episode_len:10
# kl:0.01962,lr_multiplier:0.667,loss:2.9443235397338867,entropy:2.3984501361846924,explained_var_old:0.360,explained_var_new:0.497
# batch i:208, episode_len:12
# kl:0.02054,lr_multiplier:0.667,loss:2.8754048347473145,entropy:2.4062514305114746,explained_var_old:0.414,explained_var_new:0.531
# batch i:209, episode_len:9
# kl:0.02602,lr_multiplier:0.667,loss:2.8984010219573975,entropy:2.4063384532928467,explained_var_old:0.379,explained_var_new:0.498
# batch i:210, episode_len:13
# kl:0.02339,lr_multiplier:0.667,loss:2.9447109699249268,entropy:2.3798017501831055,explained_var_old:0.362,explained_var_new:0.486
# batch i:211, episode_len:12
# kl:0.02062,lr_multiplier:0.667,loss:2.920095920562744,entropy:2.4325993061065674,explained_var_old:0.394,explained_var_new:0.512
# batch i:212, episode_len:9
# kl:0.01682,lr_multiplier:0.667,loss:2.8212904930114746,entropy:2.375643014907837,explained_var_old:0.371,explained_var_new:0.504
# batch i:213, episode_len:7
# kl:0.02561,lr_multiplier:0.667,loss:2.7917211055755615,entropy:2.358625650405884,explained_var_old:0.428,explained_var_new:0.563
# batch i:214, episode_len:9
# kl:0.02254,lr_multiplier:0.667,loss:2.9383654594421387,entropy:2.427396774291992,explained_var_old:0.397,explained_var_new:0.547
# batch i:215, episode_len:9
# kl:0.02672,lr_multiplier:0.667,loss:2.8198795318603516,entropy:2.3626136779785156,explained_var_old:0.433,explained_var_new:0.551
# batch i:216, episode_len:8
# kl:0.01792,lr_multiplier:0.667,loss:2.761690616607666,entropy:2.3733863830566406,explained_var_old:0.444,explained_var_new:0.589
# batch i:217, episode_len:18
# kl:0.02575,lr_multiplier:0.667,loss:2.8950047492980957,entropy:2.3659183979034424,explained_var_old:0.364,explained_var_new:0.487
# batch i:218, episode_len:8
# kl:0.02171,lr_multiplier:0.667,loss:2.8391573429107666,entropy:2.39165997505188,explained_var_old:0.437,explained_var_new:0.591
# batch i:219, episode_len:12
# kl:0.02177,lr_multiplier:0.667,loss:2.9120891094207764,entropy:2.4614291191101074,explained_var_old:0.435,explained_var_new:0.534
# batch i:220, episode_len:13
# kl:0.02982,lr_multiplier:0.667,loss:2.7661690711975098,entropy:2.360836982727051,explained_var_old:0.428,explained_var_new:0.565
# batch i:221, episode_len:21
# kl:0.03214,lr_multiplier:0.667,loss:2.790235996246338,entropy:2.3100173473358154,explained_var_old:0.459,explained_var_new:0.559
# batch i:222, episode_len:15
# kl:0.02045,lr_multiplier:0.667,loss:2.8750433921813965,entropy:2.301022529602051,explained_var_old:0.371,explained_var_new:0.522
# batch i:223, episode_len:10
# kl:0.02582,lr_multiplier:0.667,loss:2.797316789627075,entropy:2.352725028991699,explained_var_old:0.423,explained_var_new:0.537
# batch i:224, episode_len:14
# kl:0.01672,lr_multiplier:0.667,loss:2.795804977416992,entropy:2.388556718826294,explained_var_old:0.445,explained_var_new:0.568
# batch i:225, episode_len:13
# kl:0.01833,lr_multiplier:0.667,loss:2.8917102813720703,entropy:2.3694703578948975,explained_var_old:0.382,explained_var_new:0.526
# batch i:226, episode_len:9
# kl:0.02246,lr_multiplier:0.667,loss:2.815061330795288,entropy:2.3355677127838135,explained_var_old:0.453,explained_var_new:0.550
# batch i:227, episode_len:8
# kl:0.01973,lr_multiplier:0.667,loss:2.797419548034668,entropy:2.3104188442230225,explained_var_old:0.394,explained_var_new:0.498
# batch i:228, episode_len:7
# kl:0.02212,lr_multiplier:0.667,loss:2.7320358753204346,entropy:2.296840190887451,explained_var_old:0.456,explained_var_new:0.566
# batch i:229, episode_len:9
# kl:0.03028,lr_multiplier:0.667,loss:2.7916157245635986,entropy:2.320864677429199,explained_var_old:0.435,explained_var_new:0.550
# batch i:230, episode_len:21
# kl:0.02447,lr_multiplier:0.667,loss:2.7353880405426025,entropy:2.307159900665283,explained_var_old:0.456,explained_var_new:0.591
# batch i:231, episode_len:14
# kl:0.02395,lr_multiplier:0.667,loss:2.739284038543701,entropy:2.3517045974731445,explained_var_old:0.426,explained_var_new:0.571
# batch i:232, episode_len:10
# kl:0.02886,lr_multiplier:0.667,loss:2.7687056064605713,entropy:2.302264451980591,explained_var_old:0.433,explained_var_new:0.551
# batch i:233, episode_len:12
# kl:0.01870,lr_multiplier:0.667,loss:2.719775915145874,entropy:2.2500765323638916,explained_var_old:0.456,explained_var_new:0.559
# batch i:234, episode_len:9
# kl:0.03234,lr_multiplier:0.667,loss:2.6283602714538574,entropy:2.2133514881134033,explained_var_old:0.431,explained_var_new:0.573
# batch i:235, episode_len:13
# kl:0.02151,lr_multiplier:0.667,loss:2.7392611503601074,entropy:2.1955325603485107,explained_var_old:0.330,explained_var_new:0.497
# batch i:236, episode_len:11
# kl:0.03370,lr_multiplier:0.667,loss:2.788898468017578,entropy:2.2790303230285645,explained_var_old:0.412,explained_var_new:0.542
# batch i:237, episode_len:10
# kl:0.02153,lr_multiplier:0.667,loss:2.744541645050049,entropy:2.2976365089416504,explained_var_old:0.387,explained_var_new:0.518
# batch i:238, episode_len:14
# kl:0.02759,lr_multiplier:0.667,loss:2.872982978820801,entropy:2.3118581771850586,explained_var_old:0.280,explained_var_new:0.455
# batch i:239, episode_len:7
# kl:0.03184,lr_multiplier:0.667,loss:2.700892448425293,entropy:2.2571163177490234,explained_var_old:0.406,explained_var_new:0.556
# batch i:240, episode_len:18
# kl:0.02110,lr_multiplier:0.667,loss:2.7399237155914307,entropy:2.1974809169769287,explained_var_old:0.384,explained_var_new:0.506
# batch i:241, episode_len:7
# kl:0.02348,lr_multiplier:0.667,loss:2.659430742263794,entropy:2.227123737335205,explained_var_old:0.436,explained_var_new:0.559
# batch i:242, episode_len:10
# kl:0.02783,lr_multiplier:0.667,loss:2.678476095199585,entropy:2.2266812324523926,explained_var_old:0.420,explained_var_new:0.560
# batch i:243, episode_len:11
# kl:0.02517,lr_multiplier:0.667,loss:2.6424765586853027,entropy:2.2028841972351074,explained_var_old:0.447,explained_var_new:0.569
# batch i:244, episode_len:7
# kl:0.02697,lr_multiplier:0.667,loss:2.727363348007202,entropy:2.2255311012268066,explained_var_old:0.339,explained_var_new:0.483
# batch i:245, episode_len:13
# kl:0.02376,lr_multiplier:0.667,loss:2.6550240516662598,entropy:2.1689538955688477,explained_var_old:0.389,explained_var_new:0.520
# batch i:246, episode_len:10
# kl:0.02329,lr_multiplier:0.667,loss:2.7636380195617676,entropy:2.228322744369507,explained_var_old:0.395,explained_var_new:0.507
# batch i:247, episode_len:7
# kl:0.03271,lr_multiplier:0.667,loss:2.6336045265197754,entropy:2.265791416168213,explained_var_old:0.492,explained_var_new:0.591
# batch i:248, episode_len:11
# kl:0.03332,lr_multiplier:0.667,loss:2.6464807987213135,entropy:2.181603193283081,explained_var_old:0.372,explained_var_new:0.527
# batch i:249, episode_len:12
# kl:0.02743,lr_multiplier:0.667,loss:2.613687038421631,entropy:2.1121084690093994,explained_var_old:0.387,explained_var_new:0.554
# batch i:250, episode_len:10
# kl:0.02661,lr_multiplier:0.667,loss:2.5622329711914062,entropy:2.173581123352051,explained_var_old:0.449,explained_var_new:0.559
# current self-play batch: 250
# num_playouts:1000, win: 8, lose: 2, tie:0
# New best policy!!!!!!!!
# batch i:251, episode_len:9
# kl:0.03121,lr_multiplier:0.667,loss:2.6684787273406982,entropy:2.1952741146087646,explained_var_old:0.433,explained_var_new:0.552
# batch i:252, episode_len:22
# kl:0.02830,lr_multiplier:0.667,loss:2.6173887252807617,entropy:2.171272039413452,explained_var_old:0.464,explained_var_new:0.583
# batch i:253, episode_len:8
# kl:0.03778,lr_multiplier:0.667,loss:2.5029091835021973,entropy:2.072267532348633,explained_var_old:0.486,explained_var_new:0.586
# batch i:254, episode_len:9
# kl:0.03304,lr_multiplier:0.667,loss:2.670175552368164,entropy:2.1514999866485596,explained_var_old:0.384,explained_var_new:0.511
# batch i:255, episode_len:11
# kl:0.02455,lr_multiplier:0.667,loss:2.609475612640381,entropy:2.1985883712768555,explained_var_old:0.450,explained_var_new:0.558
# batch i:256, episode_len:15
# kl:0.03977,lr_multiplier:0.667,loss:2.5578536987304688,entropy:2.1088907718658447,explained_var_old:0.445,explained_var_new:0.574
# batch i:257, episode_len:9
# kl:0.02972,lr_multiplier:0.667,loss:2.614194631576538,entropy:2.186770439147949,explained_var_old:0.480,explained_var_new:0.591
# batch i:258, episode_len:11
# kl:0.02568,lr_multiplier:0.667,loss:2.6082088947296143,entropy:2.1650357246398926,explained_var_old:0.434,explained_var_new:0.549
# batch i:259, episode_len:7
# kl:0.02641,lr_multiplier:0.667,loss:2.568500518798828,entropy:2.2020230293273926,explained_var_old:0.449,explained_var_new:0.554
# batch i:260, episode_len:12
# kl:0.03351,lr_multiplier:0.667,loss:2.6033594608306885,entropy:2.1437416076660156,explained_var_old:0.435,explained_var_new:0.554
# batch i:261, episode_len:15
# kl:0.02289,lr_multiplier:0.667,loss:2.587555170059204,entropy:2.10709285736084,explained_var_old:0.456,explained_var_new:0.577
# batch i:262, episode_len:7
# kl:0.04535,lr_multiplier:0.444,loss:2.563441753387451,entropy:2.1190624237060547,explained_var_old:0.406,explained_var_new:0.532
# batch i:263, episode_len:13
# kl:0.01515,lr_multiplier:0.444,loss:2.6329660415649414,entropy:2.095785617828369,explained_var_old:0.356,explained_var_new:0.474
# batch i:264, episode_len:9
# kl:0.01692,lr_multiplier:0.444,loss:2.551002025604248,entropy:2.0891475677490234,explained_var_old:0.444,explained_var_new:0.548
# batch i:265, episode_len:7
# kl:0.02016,lr_multiplier:0.444,loss:2.6068201065063477,entropy:2.110292434692383,explained_var_old:0.423,explained_var_new:0.506
# batch i:266, episode_len:8
# kl:0.01370,lr_multiplier:0.444,loss:2.674769639968872,entropy:2.1370091438293457,explained_var_old:0.378,explained_var_new:0.446
# batch i:267, episode_len:8
# kl:0.01892,lr_multiplier:0.444,loss:2.54826021194458,entropy:2.0506319999694824,explained_var_old:0.426,explained_var_new:0.517
# batch i:268, episode_len:10
# kl:0.01126,lr_multiplier:0.444,loss:2.6469578742980957,entropy:2.0875017642974854,explained_var_old:0.412,explained_var_new:0.494
# batch i:269, episode_len:17
# kl:0.01619,lr_multiplier:0.444,loss:2.53826904296875,entropy:2.077683448791504,explained_var_old:0.454,explained_var_new:0.534
# batch i:270, episode_len:13
# kl:0.01571,lr_multiplier:0.444,loss:2.582681179046631,entropy:2.0991225242614746,explained_var_old:0.412,explained_var_new:0.513
# batch i:271, episode_len:19
# kl:0.01131,lr_multiplier:0.444,loss:2.482631206512451,entropy:2.0466856956481934,explained_var_old:0.472,explained_var_new:0.573
# batch i:272, episode_len:14
# kl:0.01121,lr_multiplier:0.444,loss:2.5744833946228027,entropy:2.0675227642059326,explained_var_old:0.389,explained_var_new:0.510
# batch i:273, episode_len:9
# kl:0.01105,lr_multiplier:0.444,loss:2.6448307037353516,entropy:2.098142385482788,explained_var_old:0.357,explained_var_new:0.469
# batch i:274, episode_len:17
# kl:0.01353,lr_multiplier:0.444,loss:2.6383228302001953,entropy:2.1375794410705566,explained_var_old:0.366,explained_var_new:0.461
# batch i:275, episode_len:16
# kl:0.01873,lr_multiplier:0.444,loss:2.521350860595703,entropy:2.083003044128418,explained_var_old:0.414,explained_var_new:0.511
# batch i:276, episode_len:10
# kl:0.01448,lr_multiplier:0.444,loss:2.538780450820923,entropy:2.0406155586242676,explained_var_old:0.427,explained_var_new:0.534
# batch i:277, episode_len:11
# kl:0.01989,lr_multiplier:0.444,loss:2.5689895153045654,entropy:2.0758819580078125,explained_var_old:0.425,explained_var_new:0.498
# batch i:278, episode_len:13
# kl:0.01828,lr_multiplier:0.444,loss:2.5757930278778076,entropy:2.064896821975708,explained_var_old:0.419,explained_var_new:0.493
# batch i:279, episode_len:9
# kl:0.01950,lr_multiplier:0.444,loss:2.5024139881134033,entropy:2.006131172180176,explained_var_old:0.444,explained_var_new:0.536
# batch i:280, episode_len:9
# kl:0.02310,lr_multiplier:0.444,loss:2.6108005046844482,entropy:2.0705924034118652,explained_var_old:0.352,explained_var_new:0.457
# batch i:281, episode_len:9
# kl:0.01798,lr_multiplier:0.444,loss:2.590087652206421,entropy:2.112255811691284,explained_var_old:0.425,explained_var_new:0.510
# batch i:282, episode_len:14
# kl:0.03146,lr_multiplier:0.444,loss:2.494633913040161,entropy:2.055872917175293,explained_var_old:0.484,explained_var_new:0.572
# batch i:283, episode_len:7
# kl:0.02489,lr_multiplier:0.444,loss:2.5610320568084717,entropy:2.0475761890411377,explained_var_old:0.390,explained_var_new:0.480
# batch i:284, episode_len:16
# kl:0.01832,lr_multiplier:0.444,loss:2.445768117904663,entropy:2.0327000617980957,explained_var_old:0.503,explained_var_new:0.597
# batch i:285, episode_len:8
# kl:0.01569,lr_multiplier:0.444,loss:2.4740610122680664,entropy:1.9693830013275146,explained_var_old:0.423,explained_var_new:0.531
# batch i:286, episode_len:15
# kl:0.02232,lr_multiplier:0.444,loss:2.44415020942688,entropy:1.996992588043213,explained_var_old:0.440,explained_var_new:0.547
# batch i:287, episode_len:9
# kl:0.01629,lr_multiplier:0.444,loss:2.4380691051483154,entropy:2.00761079788208,explained_var_old:0.456,explained_var_new:0.552
# batch i:288, episode_len:14
# kl:0.01508,lr_multiplier:0.444,loss:2.6024508476257324,entropy:2.0662403106689453,explained_var_old:0.360,explained_var_new:0.451
# batch i:289, episode_len:7
# kl:0.01618,lr_multiplier:0.444,loss:2.6011743545532227,entropy:2.0237929821014404,explained_var_old:0.349,explained_var_new:0.432
# batch i:290, episode_len:8
# kl:0.02239,lr_multiplier:0.444,loss:2.59834623336792,entropy:1.9961111545562744,explained_var_old:0.378,explained_var_new:0.463
# batch i:291, episode_len:9
# kl:0.01349,lr_multiplier:0.444,loss:2.495975971221924,entropy:1.9860563278198242,explained_var_old:0.370,explained_var_new:0.462
# batch i:292, episode_len:10
# kl:0.02134,lr_multiplier:0.444,loss:2.4603970050811768,entropy:1.9781110286712646,explained_var_old:0.423,explained_var_new:0.532
# batch i:293, episode_len:13
# kl:0.01346,lr_multiplier:0.444,loss:2.438302993774414,entropy:2.019455909729004,explained_var_old:0.438,explained_var_new:0.528
# batch i:294, episode_len:11
# kl:0.01798,lr_multiplier:0.444,loss:2.4275879859924316,entropy:1.946547031402588,explained_var_old:0.420,explained_var_new:0.519
# batch i:295, episode_len:7
# kl:0.02515,lr_multiplier:0.444,loss:2.4591574668884277,entropy:1.9196889400482178,explained_var_old:0.370,explained_var_new:0.492
# batch i:296, episode_len:11
# kl:0.03563,lr_multiplier:0.444,loss:2.5272529125213623,entropy:1.966644287109375,explained_var_old:0.400,explained_var_new:0.481
# batch i:297, episode_len:15
# kl:0.02315,lr_multiplier:0.444,loss:2.4114673137664795,entropy:1.9252219200134277,explained_var_old:0.423,explained_var_new:0.531
# batch i:298, episode_len:9
# kl:0.02643,lr_multiplier:0.444,loss:2.4724154472351074,entropy:2.012197256088257,explained_var_old:0.393,explained_var_new:0.498
# batch i:299, episode_len:13
# kl:0.03407,lr_multiplier:0.444,loss:2.512298345565796,entropy:1.9945127964019775,explained_var_old:0.420,explained_var_new:0.526
# batch i:300, episode_len:11
# kl:0.02588,lr_multiplier:0.444,loss:2.4635398387908936,entropy:1.9459116458892822,explained_var_old:0.375,explained_var_new:0.476
# current self-play batch: 300
# num_playouts:1000, win: 7, lose: 3, tie:0
# batch i:301, episode_len:12
# kl:0.01692,lr_multiplier:0.444,loss:2.461315631866455,entropy:2.0206942558288574,explained_var_old:0.450,explained_var_new:0.535
# batch i:302, episode_len:7
# kl:0.01924,lr_multiplier:0.444,loss:2.4485034942626953,entropy:1.9759266376495361,explained_var_old:0.413,explained_var_new:0.517
# batch i:303, episode_len:11
# kl:0.01781,lr_multiplier:0.444,loss:2.478912115097046,entropy:1.9752721786499023,explained_var_old:0.409,explained_var_new:0.500
# batch i:304, episode_len:10
# kl:0.01753,lr_multiplier:0.444,loss:2.463066577911377,entropy:1.9661294221878052,explained_var_old:0.375,explained_var_new:0.489
# batch i:305, episode_len:11
# ...
# kl:0.03688,lr_multiplier:0.444,loss:2.1657562255859375,entropy:1.601733684539795,explained_var_old:0.322,explained_var_new:0.455
# batch i:506, episode_len:12
# kl:0.02363,lr_multiplier:0.444,loss:2.1605799198150635,entropy:1.6284079551696777,explained_var_old:0.296,explained_var_new:0.403
# batch i:507, episode_len:16
# kl:0.04190,lr_multiplier:0.296,loss:2.167656898498535,entropy:1.6263415813446045,explained_var_old:0.370,explained_var_new:0.472
# batch i:508, episode_len:7
# kl:0.00663,lr_multiplier:0.444,loss:2.1553521156311035,entropy:1.6107982397079468,explained_var_old:0.398,explained_var_new:0.472
# batch i:509, episode_len:9
# kl:0.02644,lr_multiplier:0.444,loss:2.2268259525299072,entropy:1.6321831941604614,explained_var_old:0.313,explained_var_new:0.424
# batch i:510, episode_len:8
# kl:0.01524,lr_multiplier:0.444,loss:2.1702535152435303,entropy:1.619033932685852,explained_var_old:0.432,explained_var_new:0.527
# batch i:511, episode_len:7
# kl:0.02719,lr_multiplier:0.444,loss:2.1688451766967773,entropy:1.58250892162323,explained_var_old:0.321,explained_var_new:0.431
# batch i:512, episode_len:13
# kl:0.02015,lr_multiplier:0.444,loss:2.1614527702331543,entropy:1.610280156135559,explained_var_old:0.387,explained_var_new:0.488
# batch i:513, episode_len:14
# kl:0.02650,lr_multiplier:0.444,loss:2.1057496070861816,entropy:1.5654470920562744,explained_var_old:0.394,explained_var_new:0.509
# batch i:514, episode_len:10
# kl:0.01952,lr_multiplier:0.444,loss:2.092522621154785,entropy:1.5542616844177246,explained_var_old:0.397,explained_var_new:0.491
# batch i:515, episode_len:12
# kl:0.03253,lr_multiplier:0.444,loss:2.1328396797180176,entropy:1.5996129512786865,explained_var_old:0.303,explained_var_new:0.451
# batch i:516, episode_len:10
# kl:0.01749,lr_multiplier:0.444,loss:2.167239189147949,entropy:1.575645923614502,explained_var_old:0.283,explained_var_new:0.392
# batch i:517, episode_len:11
# kl:0.02821,lr_multiplier:0.444,loss:2.2437655925750732,entropy:1.6475017070770264,explained_var_old:0.278,explained_var_new:0.424
# batch i:518, episode_len:13
# kl:0.02278,lr_multiplier:0.444,loss:2.205437421798706,entropy:1.630676507949829,explained_var_old:0.324,explained_var_new:0.419
# batch i:519, episode_len:8
# kl:0.01862,lr_multiplier:0.444,loss:2.16790771484375,entropy:1.6536110639572144,explained_var_old:0.352,explained_var_new:0.449
# batch i:520, episode_len:9
# kl:0.02128,lr_multiplier:0.444,loss:2.133175849914551,entropy:1.5685267448425293,explained_var_old:0.328,explained_var_new:0.470
# batch i:521, episode_len:13
# kl:0.02987,lr_multiplier:0.444,loss:2.103799819946289,entropy:1.5929527282714844,explained_var_old:0.384,explained_var_new:0.508
# batch i:522, episode_len:12
# kl:0.02767,lr_multiplier:0.444,loss:2.121433734893799,entropy:1.5578885078430176,explained_var_old:0.331,explained_var_new:0.428
# batch i:523, episode_len:11
# kl:0.02081,lr_multiplier:0.444,loss:2.1030712127685547,entropy:1.5256990194320679,explained_var_old:0.343,explained_var_new:0.462
# batch i:524, episode_len:12
# kl:0.02621,lr_multiplier:0.444,loss:2.167731285095215,entropy:1.596380591392517,explained_var_old:0.348,explained_var_new:0.433
# batch i:525, episode_len:12
# kl:0.02659,lr_multiplier:0.444,loss:2.1630101203918457,entropy:1.6185280084609985,explained_var_old:0.370,explained_var_new:0.466
# batch i:526, episode_len:10
# kl:0.02483,lr_multiplier:0.444,loss:2.258030414581299,entropy:1.6308197975158691,explained_var_old:0.301,explained_var_new:0.421
# batch i:527, episode_len:7
# kl:0.02799,lr_multiplier:0.444,loss:2.151996612548828,entropy:1.629981279373169,explained_var_old:0.378,explained_var_new:0.456
# batch i:528, episode_len:13
# kl:0.03299,lr_multiplier:0.444,loss:2.0783419609069824,entropy:1.6091606616973877,explained_var_old:0.427,explained_var_new:0.523
# batch i:529, episode_len:9
# kl:0.04106,lr_multiplier:0.296,loss:2.0983991622924805,entropy:1.5418438911437988,explained_var_old:0.342,explained_var_new:0.474
# batch i:530, episode_len:13
# kl:0.01428,lr_multiplier:0.296,loss:2.1333327293395996,entropy:1.6118361949920654,explained_var_old:0.388,explained_var_new:0.495
# batch i:531, episode_len:15
# kl:0.01883,lr_multiplier:0.296,loss:2.2281689643859863,entropy:1.6075985431671143,explained_var_old:0.291,explained_var_new:0.396
# batch i:532, episode_len:8
# kl:0.01124,lr_multiplier:0.296,loss:2.1495280265808105,entropy:1.5888992547988892,explained_var_old:0.403,explained_var_new:0.474
# batch i:533, episode_len:13
# kl:0.01646,lr_multiplier:0.296,loss:2.190924644470215,entropy:1.629408359527588,explained_var_old:0.387,explained_var_new:0.456
# batch i:534, episode_len:11
# kl:0.01572,lr_multiplier:0.296,loss:2.2022130489349365,entropy:1.6343989372253418,explained_var_old:0.359,explained_var_new:0.444
# batch i:535, episode_len:12
# kl:0.00967,lr_multiplier:0.444,loss:2.1605820655822754,entropy:1.60491943359375,explained_var_old:0.387,explained_var_new:0.453
# batch i:536, episode_len:17
# kl:0.01620,lr_multiplier:0.444,loss:2.1215009689331055,entropy:1.6024330854415894,explained_var_old:0.401,explained_var_new:0.501
# batch i:537, episode_len:8
# kl:0.02110,lr_multiplier:0.444,loss:2.147796630859375,entropy:1.656691074371338,explained_var_old:0.367,explained_var_new:0.488
# batch i:538, episode_len:11
# kl:0.02471,lr_multiplier:0.444,loss:2.1042327880859375,entropy:1.6530879735946655,explained_var_old:0.399,explained_var_new:0.528
# batch i:539, episode_len:11
# kl:0.03376,lr_multiplier:0.444,loss:2.1434812545776367,entropy:1.5915589332580566,explained_var_old:0.375,explained_var_new:0.497
# batch i:540, episode_len:11
# kl:0.02192,lr_multiplier:0.444,loss:2.0540895462036133,entropy:1.530826210975647,explained_var_old:0.391,explained_var_new:0.496
# batch i:541, episode_len:7
# kl:0.02281,lr_multiplier:0.444,loss:2.215087890625,entropy:1.6790623664855957,explained_var_old:0.370,explained_var_new:0.482
# batch i:542, episode_len:17
# kl:0.01873,lr_multiplier:0.444,loss:2.200322151184082,entropy:1.6137816905975342,explained_var_old:0.304,explained_var_new:0.453
# batch i:543, episode_len:14
# kl:0.02840,lr_multiplier:0.444,loss:2.208791732788086,entropy:1.7000826597213745,explained_var_old:0.322,explained_var_new:0.456
# batch i:544, episode_len:7
# kl:0.02448,lr_multiplier:0.444,loss:2.0693166255950928,entropy:1.54702889919281,explained_var_old:0.377,explained_var_new:0.498
# batch i:545, episode_len:7
# kl:0.02692,lr_multiplier:0.444,loss:2.2159171104431152,entropy:1.6133357286453247,explained_var_old:0.289,explained_var_new:0.420
# batch i:546, episode_len:13
# kl:0.02721,lr_multiplier:0.444,loss:2.1693506240844727,entropy:1.6332626342773438,explained_var_old:0.341,explained_var_new:0.446
# batch i:547, episode_len:8
# kl:0.03511,lr_multiplier:0.444,loss:2.150130271911621,entropy:1.6462663412094116,explained_var_old:0.371,explained_var_new:0.496
# batch i:548, episode_len:15
# kl:0.01824,lr_multiplier:0.444,loss:2.146859645843506,entropy:1.6526062488555908,explained_var_old:0.392,explained_var_new:0.526
# batch i:549, episode_len:10
# kl:0.02971,lr_multiplier:0.444,loss:2.125302791595459,entropy:1.639068365097046,explained_var_old:0.408,explained_var_new:0.518
# batch i:550, episode_len:11
# kl:0.03367,lr_multiplier:0.444,loss:2.241678237915039,entropy:1.651252269744873,explained_var_old:0.380,explained_var_new:0.486
# current self-play batch: 550
# num_playouts:1000, win: 7, lose: 3, tie:0
# batch i:551, episode_len:11
# kl:0.01668,lr_multiplier:0.444,loss:2.153937339782715,entropy:1.6478352546691895,explained_var_old:0.400,explained_var_new:0.524
# batch i:552, episode_len:11
# kl:0.03108,lr_multiplier:0.444,loss:2.1424636840820312,entropy:1.6682686805725098,explained_var_old:0.401,explained_var_new:0.510
# batch i:553, episode_len:12
# kl:0.02423,lr_multiplier:0.444,loss:2.1853229999542236,entropy:1.7034533023834229,explained_var_old:0.339,explained_var_new:0.465
# batch i:554, episode_len:8
# kl:0.02306,lr_multiplier:0.444,loss:2.063035011291504,entropy:1.6551578044891357,explained_var_old:0.446,explained_var_new:0.568
# batch i:555, episode_len:9
# kl:0.01130,lr_multiplier:0.444,loss:2.135578155517578,entropy:1.6116493940353394,explained_var_old:0.410,explained_var_new:0.526
# batch i:556, episode_len:13
# kl:0.02283,lr_multiplier:0.444,loss:2.085026979446411,entropy:1.5986385345458984,explained_var_old:0.441,explained_var_new:0.550
# batch i:557, episode_len:8
# kl:0.02217,lr_multiplier:0.444,loss:2.1712114810943604,entropy:1.641729474067688,explained_var_old:0.416,explained_var_new:0.501
# batch i:558, episode_len:9
# kl:0.01822,lr_multiplier:0.444,loss:2.15269136428833,entropy:1.6433360576629639,explained_var_old:0.421,explained_var_new:0.534
# batch i:559, episode_len:11
# kl:0.01399,lr_multiplier:0.444,loss:2.1230568885803223,entropy:1.6766140460968018,explained_var_old:0.421,explained_var_new:0.545
# batch i:560, episode_len:8
# kl:0.01743,lr_multiplier:0.444,loss:2.279632091522217,entropy:1.7263444662094116,explained_var_old:0.351,explained_var_new:0.448
# batch i:561, episode_len:11
# kl:0.02335,lr_multiplier:0.444,loss:2.2274169921875,entropy:1.6634942293167114,explained_var_old:0.342,explained_var_new:0.450
# batch i:562, episode_len:13
# kl:0.02158,lr_multiplier:0.444,loss:2.082465887069702,entropy:1.604361891746521,explained_var_old:0.431,explained_var_new:0.531
# batch i:563, episode_len:10
# kl:0.02745,lr_multiplier:0.444,loss:2.087815523147583,entropy:1.6366171836853027,explained_var_old:0.428,explained_var_new:0.539
# batch i:564, episode_len:7
# kl:0.02258,lr_multiplier:0.444,loss:2.144881248474121,entropy:1.6662282943725586,explained_var_old:0.418,explained_var_new:0.536
# batch i:565, episode_len:7
# kl:0.01369,lr_multiplier:0.444,loss:2.2069780826568604,entropy:1.7066941261291504,explained_var_old:0.431,explained_var_new:0.529
# batch i:566, episode_len:10
# kl:0.02004,lr_multiplier:0.444,loss:2.135286331176758,entropy:1.6436488628387451,explained_var_old:0.413,explained_var_new:0.496
# batch i:567, episode_len:11
# kl:0.02197,lr_multiplier:0.444,loss:2.1509768962860107,entropy:1.6297119855880737,explained_var_old:0.364,explained_var_new:0.506
# batch i:568, episode_len:7
# kl:0.03032,lr_multiplier:0.444,loss:2.230503797531128,entropy:1.7223211526870728,explained_var_old:0.431,explained_var_new:0.512
# batch i:569, episode_len:15
# kl:0.01932,lr_multiplier:0.444,loss:2.1717586517333984,entropy:1.687693476676941,explained_var_old:0.388,explained_var_new:0.486
# batch i:570, episode_len:12
# kl:0.02968,lr_multiplier:0.444,loss:2.1115801334381104,entropy:1.6315556764602661,explained_var_old:0.386,explained_var_new:0.508
# batch i:571, episode_len:10
# kl:0.02161,lr_multiplier:0.444,loss:2.140627145767212,entropy:1.6947518587112427,explained_var_old:0.426,explained_var_new:0.527
# batch i:572, episode_len:11
# kl:0.01892,lr_multiplier:0.444,loss:2.2071566581726074,entropy:1.6837406158447266,explained_var_old:0.394,explained_var_new:0.486
# batch i:573, episode_len:9
# kl:0.02314,lr_multiplier:0.444,loss:2.1655712127685547,entropy:1.602236270904541,explained_var_old:0.367,explained_var_new:0.480
# batch i:574, episode_len:11
# kl:0.01280,lr_multiplier:0.444,loss:2.124671697616577,entropy:1.6332240104675293,explained_var_old:0.427,explained_var_new:0.541
# batch i:575, episode_len:9
# kl:0.02144,lr_multiplier:0.444,loss:2.2128915786743164,entropy:1.6734181642532349,explained_var_old:0.383,explained_var_new:0.469
# batch i:576, episode_len:13
# kl:0.01837,lr_multiplier:0.444,loss:2.2153172492980957,entropy:1.7224528789520264,explained_var_old:0.384,explained_var_new:0.508
# batch i:577, episode_len:9
# kl:0.02077,lr_multiplier:0.444,loss:2.1942036151885986,entropy:1.6590580940246582,explained_var_old:0.345,explained_var_new:0.463
# batch i:578, episode_len:7
# kl:0.03608,lr_multiplier:0.444,loss:2.1366710662841797,entropy:1.6282697916030884,explained_var_old:0.404,explained_var_new:0.516
# batch i:579, episode_len:14
# kl:0.03051,lr_multiplier:0.444,loss:2.1983861923217773,entropy:1.7272446155548096,explained_var_old:0.415,explained_var_new:0.541
# batch i:580, episode_len:9
# kl:0.02724,lr_multiplier:0.444,loss:2.1732256412506104,entropy:1.7060890197753906,explained_var_old:0.415,explained_var_new:0.517
# batch i:581, episode_len:7
# kl:0.02845,lr_multiplier:0.444,loss:2.1793441772460938,entropy:1.6839779615402222,explained_var_old:0.391,explained_var_new:0.501
# batch i:582, episode_len:8
# kl:0.02228,lr_multiplier:0.444,loss:2.140756607055664,entropy:1.659198522567749,explained_var_old:0.427,explained_var_new:0.532
# batch i:583, episode_len:10
# kl:0.02590,lr_multiplier:0.444,loss:2.1590514183044434,entropy:1.6564761400222778,explained_var_old:0.408,explained_var_new:0.509
# batch i:584, episode_len:10
# kl:0.01485,lr_multiplier:0.444,loss:2.085371732711792,entropy:1.6363861560821533,explained_var_old:0.448,explained_var_new:0.559
# batch i:585, episode_len:11
# kl:0.02480,lr_multiplier:0.444,loss:2.1980812549591064,entropy:1.6498242616653442,explained_var_old:0.406,explained_var_new:0.510
# batch i:586, episode_len:17
# kl:0.01499,lr_multiplier:0.444,loss:2.1633899211883545,entropy:1.6672749519348145,explained_var_old:0.429,explained_var_new:0.541
# batch i:587, episode_len:12
# kl:0.01889,lr_multiplier:0.444,loss:2.250598192214966,entropy:1.7578320503234863,explained_var_old:0.452,explained_var_new:0.552
# batch i:588, episode_len:8
# kl:0.01623,lr_multiplier:0.444,loss:2.2307140827178955,entropy:1.7466901540756226,explained_var_old:0.368,explained_var_new:0.496
# batch i:589, episode_len:8
# kl:0.01920,lr_multiplier:0.444,loss:2.2114086151123047,entropy:1.6794434785842896,explained_var_old:0.307,explained_var_new:0.430
# batch i:590, episode_len:13
# kl:0.01660,lr_multiplier:0.444,loss:2.1602492332458496,entropy:1.680593729019165,explained_var_old:0.409,explained_var_new:0.535
# batch i:591, episode_len:9
# kl:0.01371,lr_multiplier:0.444,loss:2.1543397903442383,entropy:1.72566556930542,explained_var_old:0.439,explained_var_new:0.538
# batch i:592, episode_len:17
# kl:0.02424,lr_multiplier:0.444,loss:2.2002415657043457,entropy:1.6742390394210815,explained_var_old:0.378,explained_var_new:0.475
# batch i:593, episode_len:14
# kl:0.02589,lr_multiplier:0.444,loss:2.175286054611206,entropy:1.6312355995178223,explained_var_old:0.366,explained_var_new:0.494
# batch i:594, episode_len:15
# kl:0.02121,lr_multiplier:0.444,loss:2.224181890487671,entropy:1.6972500085830688,explained_var_old:0.402,explained_var_new:0.513
# batch i:595, episode_len:13
# kl:0.01954,lr_multiplier:0.444,loss:2.1217284202575684,entropy:1.6440197229385376,explained_var_old:0.427,explained_var_new:0.538
# batch i:596, episode_len:10
# kl:0.01855,lr_multiplier:0.444,loss:2.222510814666748,entropy:1.670477032661438,explained_var_old:0.351,explained_var_new:0.465
# batch i:597, episode_len:7
# kl:0.01804,lr_multiplier:0.444,loss:2.256654739379883,entropy:1.7100582122802734,explained_var_old:0.345,explained_var_new:0.461
# batch i:598, episode_len:14
# kl:0.01973,lr_multiplier:0.444,loss:2.235396146774292,entropy:1.7159607410430908,explained_var_old:0.372,explained_var_new:0.481
# batch i:599, episode_len:12
# kl:0.02037,lr_multiplier:0.444,loss:2.122178554534912,entropy:1.6690363883972168,explained_var_old:0.467,explained_var_new:0.556
# batch i:600, episode_len:9
# kl:0.01636,lr_multiplier:0.444,loss:2.176187753677368,entropy:1.7068548202514648,explained_var_old:0.432,explained_var_new:0.546
# current self-play batch: 600
# num_playouts:1000, win: 7, lose: 3, tie:0
# batch i:601, episode_len:7
# kl:0.01799,lr_multiplier:0.444,loss:2.1948118209838867,entropy:1.6687514781951904,explained_var_old:0.343,explained_var_new:0.489
# batch i:602, episode_len:11
# kl:0.01982,lr_multiplier:0.444,loss:2.195767879486084,entropy:1.7021530866622925,explained_var_old:0.404,explained_var_new:0.492
# batch i:603, episode_len:14
# kl:0.02681,lr_multiplier:0.444,loss:2.187990427017212,entropy:1.650016188621521,explained_var_old:0.371,explained_var_new:0.527
# batch i:604, episode_len:8
# kl:0.02589,lr_multiplier:0.444,loss:2.1875925064086914,entropy:1.6487616300582886,explained_var_old:0.367,explained_var_new:0.474
# batch i:605, episode_len:9
# kl:0.01613,lr_multiplier:0.444,loss:2.1080970764160156,entropy:1.6499643325805664,explained_var_old:0.430,explained_var_new:0.534
# batch i:606, episode_len:15

# %% [markdown]
# kl:0.01613,lr_multiplier:0.444,loss:2.1080970764160156,entropy:1.6499643325805664,explained_var_old:0.430,explained_var_new:0.534
# batch i:606, episode_len:15
